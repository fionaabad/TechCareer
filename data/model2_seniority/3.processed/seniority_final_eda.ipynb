# %%
import pandas as pd

# %%
df = pd.read_csv("cv_with_seniority_weak.csv")

# %%
df_weak = df[~df['seniority_weak'].isna()].copy()

# %%
# Distribuciones
print(df_weak['seniority_weak'].value_counts())
# Out:
# seniority_weak
# Senior    4594
# Mid        405
# Junior     254
# Name: count, dtype: int64

# %%
# Ejemplos Junior
df_weak[df_weak['seniority_weak'] == "Junior"][['cv_id', 'role_label_final', 'cv_text']].head(3)
# Out:
#     cv_id  role_label_final  \
# 74     75  python_developer
# 77     78  python_developer
# 81     82  python_developer
#
# ...

# %%
# Ejemplos Mid
df_weak[df_weak['seniority_weak'] == "Mid"][['cv_id', 'role_label_final', 'cv_text']].head(3)
# Out:
#     cv_id  role_label_final  \
# 1       2  python_developer
# 8       9  python_developer
# 12     13  python_developer
#
# ...

# %%
# Ejemplos Senior
df_weak[df_weak['seniority_weak'] == "Senior"][['cv_id', 'role_label_final', 'cv_text']].head(3)
# Out:
#    cv_id  role_label_final  \
# 2      3  python_developer
# 3      4  python_developer
# 4      5  python_developer
#
# ...
